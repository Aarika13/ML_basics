# %% [markdown]
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#  requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text

webpage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text
webpage
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies&#63;" on this server.<P>\nReference&#32;&#35;18&#46;878c2c31&#46;1669268707&#46;1a745df9\n</BODY>\n</HTML>\n'

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
#  </head>
#  <body>
#   <h1>
#    Access Denied
#   </h1>
#   You don't have permission to access "http://www.ambitionbox.com/list-of-companies?" on this server.
#   <p>
#    Reference #18.878c2c31.1669268707.1a745df9
#   </p>
#  </body>
# </html>

# %% [markdown]
# ### Company name

# %%
soup.find_all('h1')
# Out:
# [<h1 class="bold-title-l title">List of companies in India</h1>]

# %%
soup.find_all('h1')[0].text
# Out:
# 'List of companies in India'

# %%
soup.find_all('h2')
# Out:
# [<h2 class="company-name bold-title-l" title="TCS">
#  								TCS
#  							</h2>,
#  <h2 class="company-name bold-title-l" title="Accenture">
#  								Accenture
#  							</h2>,
#  <h2 class="company-name bold-title-l" title="Cognizant">
#  								Cognizant
#  							</h2>,
#  <h2 class="company-name bold-title-l" title="ICICI Bank">
#  								ICICI Bank
#  							</h2>,
#  <h2 class="company-name bold-title-l" title="HDFC Bank">
#  								HDFC Bank
#  							</h2>,
#  <h2 class="company-name bold-title-l" title="Infosys">
#  								Infosys
#  							</h2>,
#  <h2 class="company-name bold-title-l" title="Wipro">
#  								Wipro
#  							</h2>,
#  <h2 class="company-name bold-title-l" title="Capgemini">
#  								Capgemini
#  							</h2>,
#  <h2 class="company-name bold-title-l" title="Tech Mahindra">
#  								Tech Mahindra
#  							</h2>,
#  <h2 class="company-name bold-title-l" title="Genpact">
#  								Genpact
#  							</h2>,
# ...

# %%
len(soup.find_all('h2'))
# Out:
# 30

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# ICICI Bank
# HDFC Bank
# Infosys
# Wipro
# Capgemini
# Tech Mahindra
# Genpact
# HCL Technologies
# Axis Bank
# Amazon
# IBM
# Concentrix Corpo...
# Larsen & Toubro ...
# Reliance jio
# Vodafone Idea
# HDB Financial Se...
# Teleperformance
# Kotak Mahindra B...
# Bharti Airtel
# Reliance Industr...
# Deloitte
# Tata Motors
# Reliance Retail
# Mahindra & Mahin...
# WNS
# IndusInd Bank
# Flipkart

# %% [markdown]
# ### ratings

# %%
soup.find_all('p', class_ = 'rating badge-large rating-35')
# Out:
# [<p class="rating badge-large rating-35"><i class="icon icon-star"></i>
#  								3.9
#  							</p>,
#  <p class="rating badge-large rating-35"><i class="icon icon-star"></i>
#  								3.9
#  							</p>,
#  <p class="rating badge-large rating-35"><i class="icon icon-star"></i>
#  								3.9
#  							</p>,
#  <p class="rating badge-large rating-35"><i class="icon icon-star"></i>
#  								3.9
#  							</p>,
#  <p class="rating badge-large rating-35"><i class="icon icon-star"></i>
#  								3.8
#  							</p>,
#  <p class="rating badge-large rating-35"><i class="icon icon-star"></i>
#  								3.9
#  							</p>,
#  <p class="rating badge-large rating-35"><i class="icon icon-star"></i>
#  								3.9
#  							</p>,
#  <p class="rating badge-large rating-35"><i class="icon icon-star"></i>
#  								3.6
#  							</p>,
#  <p class="rating badge-large rating-35"><i class="icon icon-star"></i>
#  								3.9
#  							</p>,
# ...

# %%
len(soup.find_all('p', class_ = 'rating'))
# Out:
# 30

# %%
for i in soup.find_all('p', class_ = 'rating badge-large rating-35'):
    print(i.text.strip())
# Out:
# 3.9
# 3.9
# 3.9
# 3.9
# 3.8
# 3.9
# 3.9
# 3.6
# 3.9
# 3.7
# 3.8

# %%
soup.find_all('a', class_ = 'review-count sbold-Labels')
# Out:
# [<a class="review-count sbold-Labels" href="https://www.ambitionbox.com/reviews/tcs-reviews">
#  								(44.5k Reviews)
#  							</a>,
#  <a class="review-count sbold-Labels" href="https://www.ambitionbox.com/reviews/accenture-reviews">
#  								(30.1k Reviews)
#  							</a>,
#  <a class="review-count sbold-Labels" href="https://www.ambitionbox.com/reviews/cognizant-reviews">
#  								(27.2k Reviews)
#  							</a>,
#  <a class="review-count sbold-Labels" href="https://www.ambitionbox.com/reviews/icici-bank-reviews">
#  								(32.8k Reviews)
#  							</a>,
#  <a class="review-count sbold-Labels" href="https://www.ambitionbox.com/reviews/hdfc-bank-reviews">
#  								(36.7k Reviews)
#  							</a>,
#  <a class="review-count sbold-Labels" href="https://www.ambitionbox.com/reviews/infosys-reviews">
#  								(26k Reviews)
#  							</a>,
#  <a class="review-count sbold-Labels" href="https://www.ambitionbox.com/reviews/wipro-reviews">
#  								(26k Reviews)
#  							</a>,
# ...

# %%
len(soup.find_all('a', class_ = 'review-count'))
# Out:
# 30

# %%
for i in soup.find_all('a', class_ = 'review-count sbold-Labels'):
    print(i.text.strip())
# Out:
# (44.5k Reviews)
# (30.1k Reviews)
# (27.2k Reviews)
# (32.8k Reviews)
# (36.7k Reviews)
# (26k Reviews)
# (26k Reviews)
# (22.1k Reviews)
# (20.1k Reviews)
# (19.7k Reviews)
# (16.7k Reviews)
# (17.8k Reviews)
# (16k Reviews)
# (19.6k Reviews)
# (14.5k Reviews)
# (23.3k Reviews)
# (13.8k Reviews)
# (13.5k Reviews)
# (12.5k Reviews)
# (13.5k Reviews)
# (12.9k Reviews)
# (11k Reviews)
# (39.6k Reviews)
# (9.6k Reviews)
# (11.3k Reviews)
# (13.7k Reviews)
# (7.4k Reviews)
# (6.5k Reviews)
# (6.5k Reviews)
# (10.1k Reviews)

# %%
soup.find_all('p',class_ = 'infoEntity sbold-list-header')
# Out:
# [<p class="infoEntity sbold-list-header"><i class="icon-domain"></i>
#  						Public
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-pin-drop"></i>
#  						Mumbai,Maharashtra + 258 more
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-access-time"></i>
#  						54 years old
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-supervisor-account"></i>
#  						1 Lakh+ Employees (India)
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-domain"></i>
#  						Public
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-pin-drop"></i>
#  						Dublin + 140 more
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-access-time"></i>
#  						33 years old
#  					</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-supervisor-account"></i>
#  						1 Lakh+ Employees (India)
#  					</p>,
# ...

# %%
len(soup.find_all('p',class_ = 'infoEntity sbold-list-header'))
# Out:
# 120

# %%
for i in soup.find_all('p',class_ = 'infoEntity sbold-list-header'):
    print(i.text.strip())
# Out:
# Public
# Mumbai,Maharashtra + 258 more
# 54 years old
# 1 Lakh+ Employees (India)
# Public
# Dublin + 140 more
# 33 years old
# 1 Lakh+ Employees (India)
# Private
# Teaneck. New Jersey. + 89 more
# 28 years old
# 1 Lakh+ Employees (India)
# Public
# Mumbai,Maharashtra + 1025 more
# 28 years old
# 1 Lakh+ Employees (India)
# Public
# Mumbai,Maharashtra + 1171 more
# 28 years old
# 1 Lakh+ Employees (India)
# Public
# Bengaluru/Bangalore,Karnataka + 121 more
# 41 years old
# 1 Lakh+ Employees (India)
# Public
# Bangalore/Bengaluru,Karnataka + 223 more
# 77 years old
# 1 Lakh+ Employees (India)
# Public
# Paris + 75 more
# 55 years old
# 1 Lakh+ Employees (India)
# Public
# Pune,Maharashtra + 202 more
# 36 years old
# 50k-1 Lakh Employees (India)
# Public
# New York,New York + 62 more
# 25 years old
# 50k-1 Lakh Employees (India)
# Public
# Noida,Uttar Pradesh + 135 more
# 31 years old
# 1 Lakh+ Employees (India)
# Public
# Mumbai,Maharashtra + 1029 more
# 29 years old
# ...

# %%
company = soup.find_all('div', class_ = 'company-content-wrapper')

# %%
len(company)
# Out:
# 30

# %%
name = []
rating = []
reviews = []
ctype = []
hq = []
old = []
employees = []



for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('p', class_ = 'rating').text.strip())
    reviews.append(i.find('a', class_ = 'review-count').text.strip())
    ctype.append(i.find_all('p', class_ = 'infoEntity')[0].text.strip())
    hq.append(i.find_all('p', class_ = 'infoEntity')[1].text.strip())
    old.append(i.find_all('p', class_ = 'infoEntity')[2].text.strip())
    employees.append(i.find_all('p', class_ = 'infoEntity')[3].text.strip())
    
    
d = {'name':name, 'rating':rating, 'reviews':reviews, 'type':ctype, 'hq':hq, 'old':old, 'employees':employees}

df = pd.DataFrame(d)

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'Cognizant',
#  'ICICI Bank',
#  'HDFC Bank',
#  'Infosys',
#  'Wipro',
#  'Capgemini',
#  'Tech Mahindra',
#  'Genpact',
#  'HCL Technologies',
#  'Axis Bank',
#  'Amazon',
#  'IBM',
#  'Concentrix Corpo...',
#  'Larsen & Toubro ...',
#  'Reliance jio',
#  'Vodafone Idea',
#  'HDB Financial Se...',
#  'Teleperformance',
#  'Kotak Mahindra B...',
#  'Bharti Airtel',
#  'Reliance Industr...',
#  'Deloitte',
#  'Tata Motors',
#  'Reliance Retail',
#  'Mahindra & Mahin...',
#  'WNS',
#  'IndusInd Bank',
#  'Flipkart']

# %%
rating
# Out:
# ['3.9',
#  '4.2',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '3.9',
#  '3.9',
#  '3.8',
#  '4.0',
#  '3.9',
#  '3.9',
#  '4.2',
#  '4.2',
#  '4.1',
#  '4.1',
#  '4.0',
#  '4.3',
#  '4.0',
#  '3.6',
#  '3.9',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.0',
#  '4.1',
#  '4.2',
#  '3.7',
#  '3.8',
#  '4.2']

# %%
reviews
# Out:
# ['(44.3k Reviews)',
#  '(30k Reviews)',
#  '(27.1k Reviews)',
#  '(32.7k Reviews)',
#  '(36.6k Reviews)',
#  '(25.9k Reviews)',
#  '(27.9k Reviews)',
#  '(21.9k Reviews)',
#  '(20k Reviews)',
#  '(19.7k Reviews)',
#  '(16.6k Reviews)',
#  '(17.7k Reviews)',
#  '(15.9k Reviews)',
#  '(19.6k Reviews)',
#  '(14.4k Reviews)',
#  '(23.3k Reviews)',
#  '(13.8k Reviews)',
#  '(13.4k Reviews)',
#  '(12.5k Reviews)',
#  '(13.4k Reviews)',
#  '(12.9k Reviews)',
#  '(11k Reviews)',
#  '(39.5k Reviews)',
#  '(9.5k Reviews)',
#  '(11.3k Reviews)',
#  '(13.7k Reviews)',
#  '(6.7k Reviews)',
#  '(6.5k Reviews)',
#  '(6.5k Reviews)',
#  '(10k Reviews)']

# %%
ctype
# Out:
# ['Public',
#  'Public',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Public',
#  'Private',
#  'Public',
#  'Private',
#  'Public',
#  'Public']

# %%
hq
# Out:
# ['Mumbai,Maharashtra + 258 more',
#  'Dublin + 139 more',
#  'Teaneck. New Jersey. + 89 more',
#  'Mumbai,Maharashtra + 1025 more',
#  'Mumbai,Maharashtra + 1169 more',
#  'Bengaluru/Bangalore,Karnataka + 121 more',
#  'Bangalore/Bengaluru,Karnataka + 224 more',
#  'Paris + 75 more',
#  'Pune,Maharashtra + 202 more',
#  'New York,New York + 62 more',
#  'Noida,Uttar Pradesh + 134 more',
#  'Mumbai,Maharashtra + 1027 more',
#  'Seattle,Washington + 338 more',
#  'Armonk,New York + 116 more',
#  'Fremont,California + 66 more',
#  'Mumbai,Maharashtra + 517 more',
#  'Navi Mumbai,Maharashtra + 933 more',
#  'Gandhinagar,Gujrat + 557 more',
#  'Ahmedabad,Gujrat + 741 more',
#  'Paris + 117 more',
#  'Mumbai,Maharashtra + 464 more',
#  'Gurgaon/Gurugram,Haryana + 481 more',
#  'Navi Mumbai,Maharashtra + 447 more',
#  'New York,New York + 131 more',
#  'Pune,Maharashtra + 381 more',
#  'Navi Mumbai,Maharashtra + 566 more',
#  'Mumbai,Maharashtra + 396 more',
# ...

# %%
old
# Out:
# ['54 years old',
#  '33 years old',
#  '28 years old',
#  '28 years old',
#  '28 years old',
#  '41 years old',
#  '77 years old',
#  '55 years old',
#  '36 years old',
#  '25 years old',
#  '31 years old',
#  '29 years old',
#  '28 years old',
#  '111 years old',
#  '39 years old',
#  '84 years old',
#  '15 years old',
#  '4 years old',
#  '15 years old',
#  '44 years old',
#  '19 years old',
#  '27 years old',
#  '49 years old',
#  '177 years old',
#  '77 years old',
#  '16 years old',
#  '77 years old',
#  '26 years old',
#  '28 years old',
#  '15 years old']

# %%
employees
# Out:
# ['1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '10k-50k Employees (India)',
#  '10k-50k Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '10k-50k Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '10k-50k Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '10k-50k Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '10k-50k Employees (India)',
#  '10k-50k Employees (India)',
#  '50k-1 Lakh Employees (India)']

# %%
df
# Out:
#                    name rating          reviews     type  \
# 0                   TCS    3.9  (44.5k Reviews)   Public
# 1             Accenture    4.2  (30.1k Reviews)   Public
# 2             Cognizant    4.0  (27.2k Reviews)  Private
# 3            ICICI Bank    4.0  (32.8k Reviews)   Public
# 4             HDFC Bank    4.0  (36.7k Reviews)   Public
# 5               Infosys    3.9    (26k Reviews)   Public
# 6                 Wipro    3.9    (26k Reviews)   Public
# 7             Capgemini    3.9  (22.1k Reviews)   Public
# 8         Tech Mahindra    3.8  (20.1k Reviews)   Public
# 9               Genpact    4.0  (19.7k Reviews)   Public
# 10     HCL Technologies    3.9  (16.7k Reviews)   Public
# 11            Axis Bank    3.9  (17.8k Reviews)   Public
# 12               Amazon    4.2    (16k Reviews)   Public
# 13                  IBM    4.2  (19.6k Reviews)   Public
# 14  Concentrix Corpo...    4.1  (14.5k Reviews)   Public
# ...

# %%
df.shape
# Out:
# (30, 7)

# %%
final = pd.DataFrame()


for j in range(1,10):
    
    url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage = requests.get(url, headers = headers).text
    
    soup = BeautifulSoup(webpage, 'lxml')
    company = soup.find_all('div', class_ = 'company-content-wrapper')
    
    name = []
    rating = []
    reviews = []
    ctype = []
    hq = []
    old = []
    employees = []



    for i in company:
        name.append(i.find('h2').text.strip())
        rating.append(i.find('p', class_ = 'rating').text.strip())
        reviews.append(i.find('a', class_ = 'review-count').text.strip())
        ctype.append(i.find_all('p', class_ = 'infoEntity')[0].text.strip())
        hq.append(i.find_all('p', class_ = 'infoEntity')[1].text.strip())
        old.append(i.find_all('p', class_ = 'infoEntity')[2].text.strip())
        try:
            employees.append(i.find_all('p', class_ = 'infoEntity')[3].text.strip())
        except:
            employees.append(np.nan)


    d = {'name':name, 'rating':rating, 'reviews':reviews, 'type':ctype, 'hq':hq, 'old':old, 'employees':employees}
    
    df = pd.DataFrame(d)
    final = pd.DataFrame(df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [39], in <cell line: 4>()
#      28 ctype.append(i.find_all('p', class_ = 'infoEntity')[0].text.strip())
#      29 hq.append(i.find_all('p', class_ = 'infoEntity')[1].text.strip())
# ---> 30 old.append(i.find_all('p', class_ = 'infoEntity')[2].text.strip())
#      31 try:
#      32     employees.append(i.find_all('p', class_ = 'infoEntity')[3].text.strip())
#
# IndexError: list index out of range

# %%
final.shape
# Out:
# (30, 7)
